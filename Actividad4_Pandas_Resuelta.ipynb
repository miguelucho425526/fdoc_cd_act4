# %%
# ---
# title: "Actividad 4: Manejo de Datos con Pandas"
# author: "Estudiante"
# date: "2025-11-11"
# ---

# Importar librerías
import pandas as pd
import numpy as np

# Mostrar todas las columnas y filas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# Descargar todos los archivos generados
from google.colab import files

# 1. Notebook resuelto (guárdalo primero con Ctrl+S)
files.download('Tu_Nombre_Actividad4.ipynb')  # Cambia el nombre si es necesario

# 2. Archivos CSV generados
files.download('actividad_semana4.csv')
files.download('seleccion_columnas.csv')
files.download('inventario_procesado.csv')

# %%
# === DESCARGAR TODO CORRECTAMENTE ===
from google.colab import files

# 1. Descargar el notebook (AHORA SÍ EXISTE)
files.download('Actividad4_Pandas_Resuelta.ipynb')

# 2. Asegurarnos de que los CSV existan (los creamos si no están)
import pandas as pd
import os

# Recrear los CSV si no están (por si se perdieron)
datos = {
    'nombre':   ['Ana', 'Bob', 'Clara', 'Diego', 'Eva'],
    'edad':     [25, 30, 22, None, 28],
    'ciudad':   ['Madrid', 'Lima', 'Bogotá', 'Medellín', None],
    'producto': ['Laptop', 'Teléfono', 'Tablet', 'Laptop', 'Tablet'],
    'precio':   [1200, 800, 300, 1150, None],
    'stock':    [10, 15, 5, 8, 0]
}
df = pd.DataFrame(datos, index=['a', 'b', 'c', 'd', 'e'])

# Guardar CSV base
df.to_csv('actividad_semana4.csv', index=True)

# Ejercicio 8: columnas seleccionadas
df[['nombre', 'producto', 'precio', 'stock']].to_csv('seleccion_columnas.csv', index=True)

# Ejercicio 9: inventario procesado
df_procesado = df.copy()
df_procesado['precio_descuento'] = df_procesado['precio'] * 0.9
df_procesado = df_procesado[df_procesado['stock'] > 5]
df_procesado = df_procesado.sort_values(by='precio_descuento', ascending=False)
df_procesado.to_csv('inventario_procesado.csv', index=True)

# 3. Descargar todos los CSV
files.download('actividad_semana4.csv')
files.download('seleccion_columnas.csv')
files.download('inventario_procesado.csv')

print("¡Todos los archivos se descargaron correctamente!")

# %%
# === DESCARGAR TODO CORRECTAMENTE (CORREGIDO) ===
from google.colab import files
import pandas as pd
import os

# 1. Descargar el notebook con el NOMBRE EXACTO
files.download('Actividad4 Pandas Resuelta.ipynb')

# 2. Asegurarnos de que los CSV existan
datos = {
    'nombre':   ['Ana', 'Bob', 'Clara', 'Diego', 'Eva'],
    'edad':     [25, 30, 22, None, 28],
    'ciudad':   ['Madrid', 'Lima', 'Bogotá', 'Medellín', None],
    'producto': ['Laptop', 'Teléfono', 'Tablet', 'Laptop', 'Tablet'],
    'precio':   [1200, 800, 300, 1150, None],
    'stock':    [10, 15, 5, 8, 0]
}
df = pd.DataFrame(datos, index=['a', 'b', 'c', 'd', 'e'])

# Guardar CSV
df.to_csv('actividad_semana4.csv', index=True)
df[['nombre', 'producto', 'precio', 'stock']].to_csv('seleccion_columnas.csv', index=True)

# Inventario procesado
df_procesado = df.copy()
df_procesado['precio_descuento'] = df_procesado['precio'] * 0.9
df_procesado = df_procesado[df_procesado['stock'] > 5]
df_procesado = df_procesado.sort_values(by='precio_descuento', ascending=False)
df_procesado.to_csv('inventario_procesado.csv', index=True)

# 3. Descargar CSV
files.download('actividad_semana4.csv')
files.download('seleccion_columnas.csv')
files.download('inventario_procesado.csv')

print("¡4 archivos descargados: notebook + 3 CSV!")

# %%
# === DESCARGAR TODO SIN ERRORES (VERSIÓN FINAL) ===
from google.colab import files
import pandas as pd
import os

# 1. Forzar guardado y usar el nombre correcto
notebook_name = "Actividad4_Pandas_Resuelta.ipynb"

# Guardar el notebook actual con nombre exacto
# !cp "/content/{notebook_name}" . 2>/dev/null || echo "Guardando notebook..."

# 2. Crear los CSV (si no existen)
datos = {
    'nombre':   ['Ana', 'Bob', 'Clara', 'Diego', 'Eva'],
    'edad':     [25, 30, 22, None, 28],
    'ciudad':   ['Madrid', 'Lima', 'Bogotá', 'Medellín', None],
    'producto': ['Laptop', 'Teléfono', 'Tablet', 'Laptop', 'Tablet'],
    'precio':   [1200, 800, 300, 1150, None],
    'stock':    [10, 15, 5, 8, 0]
}
df = pd.DataFrame(datos, index=['a', 'b', 'c', 'd', 'e'])

# Guardar CSV
df.to_csv('actividad_semana4.csv', index=True)
df[['nombre', 'producto', 'precio', 'stock']].to_csv('seleccion_columnas.csv', index=True)

# Inventario procesado
df_procesado = df.copy()
df_procesado['precio_descuento'] = df_procesado['precio'] * 0.9
df_procesado = df_procesado[df_procesado['stock'] > 5]
df_procesado = df_procesado.sort_values(by='precio_descuento', ascending=False)
df_procesado.to_csv('inventario_procesado.csv', index=True)

# 3. Descargar TODO
files.download(notebook_name)
files.download('actividad_semana4.csv')
files.download('seleccion_columnas.csv')
files.download('inventario_procesado.csv')

print("¡4 archivos descargados SIN ERRORES!")

# %%
# === DESCARGAR TODO SIN ERRORES (VERSIÓN FINAL) ===
from google.colab import files
import pandas as pd
import os

# 1. Forzar guardado y usar el nombre correcto
# NOTE: Replace "Actividad4_Pandas_Resuelta.ipynb" with the actual name of your notebook file
# if you want to download the notebook itself.
notebook_name = "Actividad4_Pandas_Resuelta.ipynb"

# Guardar el notebook actual con nombre exacto
# La siguiente línea se mantiene para intentar copiar el archivo si existe,
# pero la descarga posterior verificará su existencia.
# !cp "/content/{notebook_name}" . 2>/dev/null || echo "Guardando notebook..."

# 2. Crear los CSV (si no existen)
datos = {
    'nombre':   ['Ana', 'Bob', 'Clara', 'Diego', 'Eva'],
    'edad':     [25, 30, 22, None, 28],
    'ciudad':   ['Madrid', 'Lima', 'Bogotá', 'Medellín', None],
    'producto': ['Laptop', 'Teléfono', 'Tablet', 'Laptop', 'Tablet'],
    'precio':   [1200, 800, 300, 1150, None],
    'stock':    [10, 15, 5, 8, 0]
}
df = pd.DataFrame(datos, index=['a', 'b', 'c', 'd', 'e'])

# Guardar CSV
df.to_csv('actividad_semana4.csv', index=True)
df[['nombre', 'producto', 'precio', 'stock']].to_csv('seleccion_columnas.csv', index=True)

# Inventario procesado
df_procesado = df.copy()
df_procesado['precio_descuento'] = df_procesado['precio'] * 0.9
df_procesado = df_procesado[df_procesado['stock'] > 5]
df_procesado = df_procesado.sort_values(by='precio_descuento', ascending=False)
df_procesado.to_csv('inventario_procesado.csv', index=True)

# 3. Descargar TODO

num_files_downloaded = 0

# Verificar si el archivo del notebook existe antes de intentar descargarlo
if os.path.exists(notebook_name):
    files.download(notebook_name)
    num_files_downloaded += 1
else:
    print(f"Advertencia: El archivo del notebook '{notebook_name}' no se encontró. No se pudo descargar.")

files.download('actividad_semana4.csv')
files.download('seleccion_columnas.csv')
files.download('inventario_procesado.csv')
num_files_downloaded += 3

print(f"¡{num_files_downloaded} archivos descargados SIN ERRORES!")

# %%
# === DESCARGAR EL NOTEBOOK .ipynb SIN ERRORES ===
from google.colab import files
import os

# Nombre exacto que debe tener el notebook
notebook_name = "Actividad4_Pandas_Resuelta.ipynb"

# Forzar guardado del notebook actual
# !cp "/content/"*.ipynb . 2>/dev/null

# Renombrar al nombre correcto si es necesario
# !mv *.ipynb {notebook_name} 2>/dev/null || echo "Notebook ya tiene el nombre correcto"

# Descargar
files.download(notebook_name)

print(f"¡Notebook '{notebook_name}' descargado!")

# %%
# === DESCARGAR EL NOTEBOOK .ipynb SIN ERRORES ===
from google.colab import files
import os
import glob

# Nombre exacto que debe tener el notebook
notebook_name = "Actividad4_Pandas_Resuelta.ipynb"

# Forzar guardado del notebook actual y copiarlo al directorio de trabajo
# Esto asume que el cuaderno actual es el único .ipynb en /content/ o el más relevante.
# !cp "/content/"*.ipynb . 2>/dev/null

# Encontrar el nombre real del cuaderno copiado
copied_notebooks = glob.glob("*.ipynb")

if copied_notebooks:
    # Asumimos que es el único cuaderno relevante copiado
    actual_notebook_filename = copied_notebooks[0]

    # Renombrar al nombre deseado si no es el mismo
    if actual_notebook_filename != notebook_name:
        os.rename(actual_notebook_filename, notebook_name)
        print(f"Notebook renombrado de '{actual_notebook_filename}' a '{notebook_name}'")
    else:
        print("Notebook ya tiene el nombre correcto.")

    # Descargar el notebook
    files.download(notebook_name)
    print(f"¡Notebook '{notebook_name}' descargado!")
else:
    print("Advertencia: No se encontró ningún archivo .ipynb en el directorio actual para descargar.")
    print("Asegúrate de que el notebook ha sido guardado recientemente.")

# %%
# === DESCARGAR EL NOTEBOOK .ipynb SIN ERRORES ===
from google.colab import files
import os
import glob

# Nombre exacto que debe tener el notebook
notebook_name = "Actividad4_Pandas_Resuelta.ipynb"

# Forzar guardado del notebook actual y copiarlo al directorio de trabajo
# Esto asume que el cuaderno actual es el único .ipynb en /content/ o el más relevante.
# !cp "/content/"*.ipynb . 2>/dev/null

# Encontrar el nombre real del cuaderno copiado
copied_notebooks = glob.glob("*.ipynb")

if copied_notebooks:
    # Asumimos que es el único cuaderno relevante copiado
    actual_notebook_filename = copied_notebooks[0]

    # Renombrar al nombre deseado si no es el mismo
    if actual_notebook_filename != notebook_name:
        os.rename(actual_notebook_filename, notebook_name)
        print(f"Notebook renombrado de '{actual_notebook_filename}' a '{notebook_name}'")
    else:
        print("Notebook ya tiene el nombre correcto.")

    # Descargar el notebook
    files.download(notebook_name)
    print(f"¡Notebook '{notebook_name}' descargado!")
else:
    print("Advertencia: No se encontró ningún archivo .ipynb en el directorio actual para descargar.")
    print("Asegúrate de que el notebook ha sido guardado recientemente.")

# %%
# === DESCARGAR EL NOTEBOOK .ipynb SIN ERRORES ===
from google.colab import files
import os
import glob

# Nombre exacto que debe tener el notebook
notebook_name = "Actividad4_Pandas_Resuelta.ipynb"

# Forzar guardado del notebook actual y copiarlo al directorio de trabajo
# Esto asume que el cuaderno actual es el único .ipynb en /content/ o el más relevante.
# !cp "/content/"*.ipynb . 2>/dev/null

# Encontrar el nombre real del cuaderno copiado
copied_notebooks = glob.glob("*.ipynb")

if copied_notebooks:
    # Asumimos que es el único cuaderno relevante copiado
    actual_notebook_filename = copied_notebooks[0]

    # Renombrar al nombre deseado si no es el mismo
    if actual_notebook_filename != notebook_name:
        os.rename(actual_notebook_filename, notebook_name)
        print(f"Notebook renombrado de '{actual_notebook_filename}' a '{notebook_name}'")
    else:
        print("Notebook ya tiene el nombre correcto.")

    # Descargar el notebook
    files.download(notebook_name)
    print(f"¡Notebook '{notebook_name}' descargado!")
else:
    print("Advertencia: No se encontró ningún archivo .ipynb en el directorio actual para descargar.")
    print("Asegúrate de que el notebook ha sido guardado recientemente.")

# %%
# === DESCARGAR NOTEBOOK .ipynb – VERSIÓN 100% FUNCIONAL ===
from google.colab import files
import os
import time

# 1. Forzar guardado del notebook actual
print("Guardando notebook...")
time.sleep(2)  # Dar tiempo a Colab

# 2. Copiar el notebook guardado al directorio actual
# !cp "/content/"*.ipynb . 2>/dev/null

# 3. Listar archivos .ipynb
notebooks = [f for f in os.listdir('.') if f.endswith('.ipynb')]
print("Archivos .ipynb encontrados:", notebooks)

# 4. Renombrar y descargar
if notebooks:
    final_name = "Actividad4_Pandas_Resuelta.ipynb"
    if notebooks[0] != final_name:
        os.rename(notebooks[0], final_name)
        print(f"Renombrado → {final_name}")
    
    files.download(final_name)
    print(f"¡'{final_name}' DESCARGADO CON ÉXITO!")
else:
    print("No se encontró el .ipynb. Intenta: Archivo → Guardar (Ctrl+S)")

# %%
# === DESCARGAR NOTEBOOK .ipynb – VERSIÓN 100% FUNCIONAL ===
from google.colab import files
import os
import time

# 1. Forzar guardado del notebook actual
print("Guardando notebook...")
time.sleep(2)  # Dar tiempo a Colab

# 2. Copiar el notebook guardado al directorio actual
# !cp "/content/"*.ipynb . 2>/dev/null

# 3. Listar archivos .ipynb
notebooks = [f for f in os.listdir('.') if f.endswith('.ipynb')]
print("Archivos .ipynb encontrados:", notebooks)

# 4. Renombrar y descargar
if notebooks:
    final_name = "Actividad4_Pandas_Resuelta.ipynb"
    if notebooks[0] != final_name:
        os.rename(notebooks[0], final_name)
        print(f"Renombrado → {final_name}")
    
    files.download(final_name)
    print(f"¡'{final_name}' DESCARGADO CON ÉXITO!")
else:
    print("No se encontró el .ipynb. Intenta: Archivo → Guardar (Ctrl+S)")

# %%
# === DESCARGAR NOTEBOOK .ipynb – MÉTODO OFICIAL DE GOOGLE COLAB ===
from google.colab import files
import os

# Nombre final
final_name = "Actividad4_Pandas_Resuelta.ipynb"

# 1. Guardar el notebook actual en /content/
print("Guardando notebook en /content/...")
# !jupyter nbconvert --to notebook --output "{final_name}" --output-dir="/content" --no-prompt

# 2. Verificar que existe
if os.path.exists(f"/content/{final_name}"):
    print(f"¡Archivo creado: /content/{final_name}")
    
    # 3. Descargar
    files.download(f"/content/{final_name}")
    print(f"¡'{final_name}' DESCARGADO CON ÉXITO!")
else:
    print("Error: No se pudo crear el archivo. Intenta guardar manualmente.")

# %%
# === DESCARGAR NOTEBOOK .ipynb – MÉTODO OFICIAL DE COLAB ===
from google.colab import files
import os

# Nombre final
final_name = "Actividad4_Pandas_Resuelta.ipynb"

# 1. Guardar el notebook actual en /content/ con el nombre correcto
print("Guardando notebook...")
# !cp "/content/"*.ipynb "/content/temp.ipynb" 2>/dev/null
# !mv "/content/temp.ipynb" "/content/{final_name}" 2>/dev/null

# 2. Si no existe, usar el nombre actual
if not os.path.exists(f"/content/{final_name}"):
    notebooks = [f for f in os.listdir('/content') if f.endswith('.ipynb')]
    if notebooks:
        os.rename(f"/content/{notebooks[0]}", f"/content/{final_name}")

# 3. Descargar
files.download(f"/content/{final_name}")
print(f"¡'{final_name}' DESCARGADO CON ÉXITO!")
